# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import OneHotEncoder
import plotly.express as px

# %%
amazon_df=pd.read_csv("./data set/amazon_phone_dataset.csv")

# %%
amazon_df.head(5)
# Out:
#                                         Product_name  by_info  \
# 0            Samsung Galaxy M10 (Ocean Blue, 3+32GB)  Samsung
# 1         Redmi 6 Pro (Black, 4GB RAM, 64GB Storage)       Mi
# 2  Coolpad Cool 3 Plus (Ocean Blue, 2GB RAM, 16GB...  Coolpad
# 3         Redmi 6 Pro (Black, 3GB RAM, 32GB Storage)       Mi
# 4                                  Nokia 105 (Black)    Nokia
#
#                                          Product_url  \
# 0  https://www.amazon.in/Samsung-Galaxy-Ocean-Blu...
# 1  https://www.amazon.in/Redmi-Pro-Black-64GB-Sto...
# 2  https://www.amazon.in/Coolpad-Cool-Plus-Ocean-...
# 3  https://www.amazon.in/Redmi-Pro-Black-32GB-Sto...
# 4  https://www.amazon.in/Nokia-105-Black/dp/B0745...
#
#                                          Product_img Product_price  \
# 0  https://images-na.ssl-images-amazon.com/images...    ₹ 7,990.00
# 1  https://images-na.ssl-images-amazon.com/images...           NaN
# ...

# %%
amazon_df.tail(5)
# Out:
#                                            Product_name      by_info  \
# 9565  Ktrack Metal and Plastic Open Pry Screwdriver ...       Ktrack
# 9566  Samsung S-View Flip Cover for Samsung Galaxy S...      Samsung
# 9567  TheGiftKart Full Body 3 in 1 Slim Fit 360 Degr...  TheGiftKart
# 9568                                                NaN          NaN
# 9569                                                NaN          NaN
#
#                                             Product_url  \
# 9565  https://www.amazon.in/Ktrack-Plastic-Screwdriv...
# 9566  https://www.amazon.in/Samsung-S-View-Flip-Cove...
# 9567  https://www.amazon.in/TheGiftKart-Degree-Prote...
# 9568  https://www.amazon.in/Mi-Basic-2-Bluetooth-Spe...
# 9569  https://www.amazon.in/Wonderford-Locust-Adjust...
#
#                                             Product_img Product_price  \
# 9565                                                NaN           NaN
# ...

# %%
amazon_df.describe()
# Out:
#                                              Product_name         by_info  \
# count                                                4176            4167
# unique                                               3607            1235
# top     Smart Fitness Band, Muzili Activity Tracker wi...  Amazon Renewed
# freq                                                    5              96
#
#          Product_url                                        Product_img  \
# count           9570                                               2935
# unique          9568                                               2420
# top      Fingerprint  https://images-na.ssl-images-amazon.com/images...
# freq               2                                                  7
#
#        Product_price              rating       total_review  \
# count           2926                3439               3441
# unique           812                  45                572
# ...

# %%
amazon_df.isnull().sum()
# Out:
# Product_name     5394
# by_info          5403
# Product_url         0
# Product_img      6635
# Product_price    6644
# rating           6131
# total_review     6129
# ans_ask          7221
# prod_des         6156
# feature          5413
# cust_review      6128
# dtype: int64

# %%
amazon_df.shape
# Out:
# (9570, 11)

# %%
amazon_info=amazon_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9570 entries, 0 to 9569
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Product_name   4176 non-null   object
#  1   by_info        4167 non-null   object
#  2   Product_url    9570 non-null   object
#  3   Product_img    2935 non-null   object
#  4   Product_price  2926 non-null   object
#  5   rating         3439 non-null   object
#  6   total_review   3441 non-null   object
#  7   ans_ask        2349 non-null   object
#  8   prod_des       3414 non-null   object
#  9   feature        4157 non-null   object
#  10  cust_review    3442 non-null   object
# dtypes: object(11)
# memory usage: 822.5+ KB

# %%
amazon_df.rating
# Out:
# 0       4.0 out of 5 stars
# 1       4.1 out of 5 stars
# 2       3.1 out of 5 stars
# 3       4.1 out of 5 stars
# 4       4.1 out of 5 stars
#                ...
# 9565    2.9 out of 5 stars
# 9566    3.9 out of 5 stars
# 9567    3.6 out of 5 stars
# 9568                   NaN
# 9569                   NaN
# Name: rating, Length: 9570, dtype: object

# %%
new_amazon_df4=amazon_df.fillna(method="bfill")

# %%
new_amazon_df4
# Out:
#                                            Product_name      by_info  \
# 0               Samsung Galaxy M10 (Ocean Blue, 3+32GB)      Samsung
# 1            Redmi 6 Pro (Black, 4GB RAM, 64GB Storage)           Mi
# 2     Coolpad Cool 3 Plus (Ocean Blue, 2GB RAM, 16GB...      Coolpad
# 3            Redmi 6 Pro (Black, 3GB RAM, 32GB Storage)           Mi
# 4                                     Nokia 105 (Black)        Nokia
# ...                                                 ...          ...
# 9565  Ktrack Metal and Plastic Open Pry Screwdriver ...       Ktrack
# 9566  Samsung S-View Flip Cover for Samsung Galaxy S...      Samsung
# 9567  TheGiftKart Full Body 3 in 1 Slim Fit 360 Degr...  TheGiftKart
# 9568                                                NaN          NaN
# 9569                                                NaN          NaN
#
#                                             Product_url  \
# 0     https://www.amazon.in/Samsung-Galaxy-Ocean-Blu...
# ...

# %%
new_amazon_df4.isna().sum()
# Out:
# Product_name     2
# by_info          2
# Product_url      0
# Product_img      2
# Product_price    3
# rating           2
# total_review     2
# ans_ask          2
# prod_des         2
# feature          2
# cust_review      2
# dtype: int64

# %%
new_amazon_df5 = new_amazon_df4.dropna()

# %%
new_amazon_df5
# Out:
#                                            Product_name    by_info  \
# 0               Samsung Galaxy M10 (Ocean Blue, 3+32GB)    Samsung
# 1            Redmi 6 Pro (Black, 4GB RAM, 64GB Storage)         Mi
# 2     Coolpad Cool 3 Plus (Ocean Blue, 2GB RAM, 16GB...    Coolpad
# 3            Redmi 6 Pro (Black, 3GB RAM, 32GB Storage)         Mi
# 4                                     Nokia 105 (Black)      Nokia
# ...                                                 ...        ...
# 9562  TokyoTon Mobile Battery for Moto M XT1662 XT16...   Tokyoton
# 9563  AM Safe x Cable for iPhone LED Fast Charging D...  AM Safe x
# 9564  Ktrack Metal and Plastic Open Pry Screwdriver ...     Ktrack
# 9565  Ktrack Metal and Plastic Open Pry Screwdriver ...     Ktrack
# 9566  Samsung S-View Flip Cover for Samsung Galaxy S...    Samsung
#
#                                             Product_url  \
# 0     https://www.amazon.in/Samsung-Galaxy-Ocean-Blu...
# ...

# %%
new_amazon_df5.isna().sum()
# Out:
# Product_name     0
# by_info          0
# Product_url      0
# Product_img      0
# Product_price    0
# rating           0
# total_review     0
# ans_ask          0
# prod_des         0
# feature          0
# cust_review      0
# dtype: int64

# %%
new_amazon_df5.shape
# Out:
# (9567, 11)
